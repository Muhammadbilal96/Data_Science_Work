# %% [markdown]
# # Bar Plot

# %% [markdown]
# # Import Lib

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import DataSet

# %%
phool = sns.load_dataset("iris")

phool

sns.barplot(x="species" , y="sepal_width" , data=phool)
plt.show()

# %%
phool = sns.load_dataset("iris")

phool

sns.barplot(x="species" , y="sepal_length" , data=phool)
plt.show()

# %%
kashti = sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti = sns.load_dataset("titanic")
kashti

sns.barplot(x="sex" , y="survived" , data=kashti)
plt.show()

# %%
kashti = sns.load_dataset("titanic")
kashti

sns.barplot(x="sex" , y="survived" , hue="who" , data=kashti)
plt.show()

# %%
kashti = sns.load_dataset("titanic")
kashti

sns.barplot(x="sex" , y="age" , hue="who" , data=kashti)
plt.show()

# %%
kashti = sns.load_dataset("titanic")
kashti

sns.barplot(x="sex" , y="age" , hue="who" , data=kashti)
plt.show()

# %%
kashti = sns.load_dataset("titanic")
kashti

sns.barplot(x="sex" , y="survived" , hue="who" , data=kashti)
plt.show()

# %%
kashti = sns.load_dataset("titanic")
kashti

sns.barplot(x="sex" , y="alone" , hue="who" , data=kashti)
plt.show()

# %%
kashti = sns.load_dataset("titanic")
kashti

sns.barplot(x="sex" , y="survived" , hue="who" , data=kashti , order=["female","male"])
plt.show()

# %%
kashti = sns.load_dataset("titanic")
kashti

sns.barplot(x="sex" , y="survived" , hue="who" , data=kashti , order=["female","male"], color="blue")
plt.show()

# %%
kashti = sns.load_dataset("titanic")
kashti

sns.barplot(x="sex" , y="survived" , hue="who" , data=kashti , order=["female","male"], color="blue" , ci=None)
plt.show()

# %%
kashti = sns.load_dataset("titanic")
kashti

sns.barplot(x="sex" , y="survived" , hue="who" , data=kashti , order=["female","male"], color="blue" , ci=None ,
           palette="pastel")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import median

kashti = sns.load_dataset("titanic")
kashti

sns.barplot(x="sex" , y="fare" , hue="who" , data=kashti , order=["female","male"], color="blue" , estimator=median ,
           palette="pastel")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy 

kashti = sns.load_dataset("titanic")
kashti

sns.barplot(x="sex" , y="fare" , hue="who" , data=kashti , order=["female","male"], color="blue" , estimator=median ,
           palette="pastel")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy 

kashti = sns.load_dataset("titanic")
kashti

sns.barplot(x="sex" , y="fare" , hue="who" , data=kashti , order=["female","male"], color="blue" , estimator=mean ,
           palette="pastel")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy 

kashti = sns.load_dataset("titanic")
kashti

sns.barplot(x="class" , y="fare" , hue="sex" , data=kashti , estimator=mean , saturation=5)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy 

kashti = sns.load_dataset("titanic")
kashti

sns.barplot(x="fare" , y="class" , hue="sex" , data=kashti , estimator=mean , saturation=1)
plt.show()
